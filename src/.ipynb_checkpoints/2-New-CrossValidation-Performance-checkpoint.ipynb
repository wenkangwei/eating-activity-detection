# %% [markdown]
# # Note:
# 1. when **adding new individual dataset**, the balance ratio will change. In this case, we need to **test the time metric again.**

# %%
# from packages import *
import sys
import numpy as np
from numpy.random import seed
### imports
import os
os.environ['TF_CPP_MIN_LOG_LEVEL'] = '3' # Turn off TensorFlow logging
import tensorflow as tf

import numpy as np
import pandas as pd
import torch
import sklearn
import seaborn as sns
import matplotlib.pyplot as plt
# %matplotlib inline
import random
#from sklearn.metrics import classification_report, confusion_matrix
from datetime import datetime
import loadfile
import addons

import keras
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Dense, Dropout, Flatten, Reshape, Activation
from tensorflow.keras.layers import Conv1D, MaxPooling1D, GlobalAveragePooling1D, Input, add
# from tensorflow.keras.utils import np_utils
from tensorflow.keras.regularizers import l1
from tensorflow.keras.models import load_model, save_model, Model


from dataset import create_train_test_file_list, Person_MealsDataset, balance_data_indices
from utils import *
from model import *

# %%
from dataset import *
from hysteresis_threshold import *
from cross_validation import *
from train_model import *

# %%
shimmer_global_mean = [-0.012359981,-0.0051663737,0.011612018,
                        0.05796114,0.1477952,-0.034395125 ]

shimmer_global_stddev = [0.05756385,0.040893298,0.043825723,
                        17.199743,15.311142,21.229317 ]

shimmer_trended_mean = [-0.000002,-0.000002,-0.000000,
                0.058144,0.147621,-0.033260 ]

shimmer_trended_stddev = [0.037592,0.034135,0.032263,
                17.209038,15.321441,21.242532 ]

all_zero_means = [0,0,0,0,0,0]

meanvals = all_zero_means
stdvals = shimmer_trended_stddev


random_seed  = 1000

# %%
def seed_everything(seed= 1000):
    np.random.seed(seed)
    random.seed(seed)
    tf.random.set_seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    torch.manual_seed(seed)
    torch.cuda.manual_seed(seed)
    torch.backends.cudnn.deterministic = True
    torch.backends.cudnn.benchmark = True
    
seed_everything(seed= random_seed)

# %%
def acti_model(input_shape):
        
        model = Sequential()
        
        model.add(Conv1D(10, 44, strides=2,activation='relu', input_shape=input_shape))
        model.add(Conv1D(10, 20, strides=2, activation='relu',kernel_regularizer=tf.keras.regularizers.l1(0.01)))
        model.add(Conv1D(10, 4, strides=2, activation='relu',kernel_regularizer=tf.keras.regularizers.l1(0.01)))
        model.add(GlobalAveragePooling1D())
        model.add(Dense(200, activation='relu'))
        model.add(Dense(1, activation='sigmoid'))
        return model

# %%
# name_ls = ["mohammad"]
# for name in name_ls:
#     create_train_test_file_list(file_name= "all_files_list.txt",person_name =name,
#                          out_path = "../data-file-indices/",root_path= "../",
#                          test_ratio = 0.2, print_flag = True, shuffle=True, random_state=random_seed)

# %%
name_ls = ["wenkanw",'adam',"lawler","shaurya","tianyi","james","cameron","zeyu","mohammad"]
dataset_info = get_dataset_info(names= name_ls)
dataset_info
# Out:
#      dataset  Days Total Hours Meal Counts Average Meal Counts Per Day  \
# 0    wenkanw    17       129.2          32                         1.9
# 1       adam    14       125.6          26                         1.9
# 2     lawler    23       167.2          60                         2.6
# 3    shaurya    13         134          38                         2.9
# 4     tianyi    14       127.8          20                         1.4
# 5      james    12       144.8          26                         2.2
# 6    cameron    10       120.4          22                         2.2
# 7       zeyu    12       115.5          22                         1.8
# 8   mohammad     6        58.4           8                         1.3
# 9      total   121      1122.9         254                         2.1
# 10   average  13.4       124.8        28.2                         2.1
#
#    Average Hours Per Meal Eating Hours No Eating Hours  \
# 0                     0.2          7.7           121.5
# ...

# %%
# name_ls = ["wenkanw",'adam',"lawler","shaurya","tianyi","james"]
# dataset_info = get_dataset_info(names= name_ls)
# dataset_info
# Out:
#    dataset  Days Total Hours Meal Counts Average Meal Counts Per Day  \
# 0  wenkanw    17       129.2          32                         1.9
# 1     adam    14       125.6          26                         1.9
# 2   lawler    23       167.2          60                         2.6
# 3  shaurya    13         134          38                         2.9
# 4   tianyi    14       127.8          20                         1.4
# 5    james    12       144.8          26                         2.2
# 6    total    93       828.6         202                         2.2
# 7  average  15.5       138.1        33.7                         2.2
#
#   Average Hours Per Meal Eating Hours No Eating Hours  \
# 0                    0.2          7.7           121.5
# 1                    0.1          3.3           122.3
# 2                    0.1          7.6           159.6
# 3                    0.2          9.3           124.7
# 4                    0.3          5.9           121.9
# ...

# %%
balance_ratio = dataset_info[dataset_info["dataset"]=="total"]['Balance Ratio(no_eat/eat)'].values[0]
balance_ratio
# Out:
# 17.0

# %%
dataset_info.to_csv("../results/dataset_info.csv",index=False)

# %% [markdown]
# # 2. Train group model if necessary

# %%
# person="CAD"
# winmin= 6
# stridesec = 15
# win_size = 15*winmin*60
# model_g = acti_model(input_shape =(win_size,6) )
# model_g.compile(loss='binary_crossentropy',
#                 optimizer='adam', metrics=['accuracy'])
# perf_df_g, model_ls_g, hist_ls_g = train_models(model_g,win_ls = [winmin],EPOCHS = 20,stridesec = stridesec,model_name="test",name = person,split_day=False)

# %% [markdown]
# # 3. Cross validation with Group Parameters

# %%
hy_threshold = {'wenkanw':[0.8,0.3], 'adam':[0.8,0.3],'lawler':[0.8,0.3], 'shaurya':[0.8,0.3]}

# %time meal_info, time_perf1,episode_perf1 = cross_validation_metrics(balance_ratio= balance_ratio, model_arch = acti_model, fold_num = 5, winmin=6, stridesec = 5, \
                                                             names= ["wenkanw","adam","lawler","shaurya"],model_name= "acti_model", \
                                                             random_seed=random_seed,  test_balance=False, re_train =False, \
                                                             test_CAD=False, metrics =['time','episode'], load_data =True, ind_threshold =hy_threshold)

episode_perf1 = pd.merge(left=meal_info,right=episode_perf1,on="dataset")

# %%
## double check result
print_episode_metrics(episode_perf1)
# Out:
# <ipython-input-16-7c20ec5f775e>:54: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df[key] = result_df[key].values.round(round_decimal)
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4  average performance    -          -           -        -
#
#   TPR: Individual-Model TPR: GroupModel FP/TP: Individual-Model  \
# 0                 0.969           0.625                   0.613
# 1                 0.923           0.923                   0.417
# ...

# %%
print_time_metrics(time_perf1)
# Out:
#                dataset win(sec) WAcc: GroupModel WAcc2: GroupModel  \
# 0              wenkanw      360            0.779             0.761
# 1                 adam      360            0.956             0.947
# 2               lawler      360            0.605             0.615
# 3              shaurya      360            0.759             0.733
# 4  average performance        -            0.775             0.764
#
#   WAcc: Individual-Model WAcc2: Individual-Model F1: GroupModel  \
# 0                    0.9                   0.892          0.423
# 1                  0.959                   0.961          0.433
# 2                  0.721                   0.728          0.132
# 3                  0.766                   0.743          0.409
# 4                  0.836                   0.831          0.349
#
#   F1: Individual-Model Precision: GroupModel Precision: Individual-Model  \
# 0                0.639                 0.319                        0.52
# ...

# %%
episode_comparison_perf = print_episode_metrics(episode_perf1)
episode_comparison_perf
# Out:
# /home/wenkanw/Thesis-Research/src/metrics.py:256: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   result_df[key] = result_df[key].values.round(round_decimal)
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4  average performance    -          -           -        -
#
#   TPR: Individual-Model TPR: GroupModel FP/TP: Individual-Model  \
# 0                 0.969           0.625                   0.613
# 1                 0.923           0.923                   0.417
# ...

# %%
time_comparison_perf = print_time_metrics(time_perf1)
time_comparison_perf
# Out:
#                dataset win(sec) WAcc: GroupModel WAcc2: GroupModel  \
# 0              wenkanw      360            0.779             0.762
# 1                 adam      360            0.956             0.947
# 2               lawler      360            0.605             0.616
# 3              shaurya      360            0.759             0.734
# 4  average performance        -            0.775             0.765
#
#   WAcc: Individual-Model WAcc2: Individual-Model F1: GroupModel  \
# 0                    0.9                   0.893          0.423
# 1                  0.959                   0.961          0.433
# 2                  0.721                   0.729          0.132
# 3                  0.766                   0.744          0.409
# 4                  0.836                   0.832          0.349
#
#   F1: Individual-Model Precision: GroupModel Precision: Individual-Model  \
# 0                0.639                 0.319                        0.52
# ...

# %%
save_path = "../results/"
time_comparison_perf.to_csv(save_path+"time_metrics/updated_cv_fold5_time_metrics.csv",index=False)
episode_comparison_perf.to_csv(save_path+"episode_metrics/updated_cv_fold5_episode_metrics.csv",index=False)

# %% [markdown]
# # Update data

# %%
save_path = "../results/"
time_comparison_perf = pd.read_csv(save_path+"time_metrics/updated_cv_fold5_time_metrics.csv")
episode_comparison_perf = pd.read_csv(save_path+"episode_metrics/updated_cv_fold5_episode_metrics.csv")

# %%
hy_threshold = {'wenkanw':[0.8,0.3], 'adam':[0.8,0.3],'lawler':[0.8,0.3], 'shaurya':[0.8,0.3],'tianyi':[0.8,0.3],'james':[0.8,0.3]}

# %time meal_info, time_perf2,episode_perf2 = cross_validation_metrics(balance_ratio= balance_ratio, model_arch = acti_model, fold_num = 5, winmin=6, stridesec = 5, \
                                                             names= ["tianyi","james"],model_name= "acti_model", \
                                                             random_seed=random_seed,  test_balance=False, re_train =False, \
                                                             test_CAD=False, metrics =['time','episode'], load_data =True, ind_threshold =hy_threshold)

episode_perf2 = pd.merge(left=meal_info,right=episode_perf2,on="dataset")

# %%
time_perf2
# Out:
#   dataset  win(sec)  WAcc: GroupModel  WAcc2: GroupModel  Recall: GroupModel  \
# 0  tianyi       360          0.833118           0.828257            0.735714
# 1   james       360          0.786936           0.786705            0.729783
#
#    Precision: GroupModel  F1: GroupModel  Acc: GroupModel  \
# 0               0.340776        0.455541         0.920024
# 1               0.193959        0.303014         0.838313
#
#    WAcc: Individual-Model  WAcc2: Individual-Model  Recall: Individual-Model  \
# 0                0.843327                 0.839780                  0.759740
# 1                0.799150                 0.795242                  0.769869
#
#    Precision: Individual-Model  F1: Individual-Model  Acc: Individual-Model
# 0                     0.359461              0.474076               0.918013
# 1                     0.205629              0.310531               0.824870

# %%
episode_perf2
# Out:
#   dataset  Days  Meal_Hours  Meal_Counts  Total_Hours  win(sec)  \
# 0  tianyi    14           5           20          127       360
# 1   james    12           6           26          144       360
#
#    TP: GroupModel  FP: GroupModel  FN: GroupModel  TP: Individual-Model  \
# 0              15              19               5                    12
# 1              23              39               3                    24
#
#    FP: Individual-Model  FN: Individual-Model  TPR: Individual-Model  \
# 0                    26                     8               0.600000
# 1                    50                     2               0.923077
#
#    FP/TP: Individual-Model  TPR: GroupModel  FP/TP: GroupModel
# 0                 2.166667         0.750000           1.266667
# 1                 2.083333         0.884615           1.695652

# %%
episode_comparison_perf
# Out:
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4  average performance    -          -           -        -
#
#    TPR: Individual-Model  TPR: GroupModel  FP/TP: Individual-Model  \
# 0                  0.969            0.625                    0.613
# 1                  0.923            0.923                    0.417
# 2                  0.667            0.333                    1.200
# 3                  0.763            0.789                    1.759
# 4                  0.830            0.668                    0.997
#
#    FP/TP: GroupModel  TP: Individual-Model  TP: GroupModel  \
# 0              0.300                  31.0            20.0
# 1              0.333                  24.0            24.0
# ...

# %%
time_comparison_perf
# Out:
#                dataset win(sec)  WAcc: GroupModel  WAcc2: GroupModel  \
# 0              wenkanw      360             0.779              0.762
# 1                 adam      360             0.956              0.947
# 2               lawler      360             0.605              0.616
# 3              shaurya      360             0.759              0.734
# 4  average performance        -             0.775              0.765
#
#    WAcc: Individual-Model  WAcc2: Individual-Model  F1: GroupModel  \
# 0                   0.900                    0.893           0.423
# 1                   0.959                    0.961           0.433
# 2                   0.721                    0.729           0.132
# 3                   0.766                    0.744           0.409
# 4                   0.836                    0.832           0.349
#
#    F1: Individual-Model  Precision: GroupModel  Precision: Individual-Model  \
# ...

# %%
# def print_time_metrics(result, old_result = None,round_decimal = 3,):
#     perf_df = pd.DataFrame()
#     mykeys = ["dataset","win(sec)","WAcc", "F1","Precision","Recall"]
#     numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']    
#     for k in mykeys:
#         for key in result.keys():
#             if k in key:
#                 perf_df[key] = result[key]
#                 if result[key].dtype in numerics:
#                     perf_df[key] = np.round(perf_df[key],round_decimal)
#     for key in result.keys():
#         if "WAcc" not in key and "Acc" in key:
#             perf_df[key] = result[key].values.round(round_decimal)
    
#     if not isinstance(old_result, type(None)):
#         # remove average performance from old results and append new data to table
#         drop_vals = result["dataset"].values.tolist()
#         drop_vals.append("average performance")
#         idx = []
#         for i in range(len(old_result)):
#             if old_result['dataset'].iloc[i] in drop_vals:
#                 idx.append(i)
                
#         #idx =old_result[(old_result['dataset']=="average performance") | (old_result['dataset']==result["dataset"].values[0])].index
#         print("index",idx)
#         new_result = old_result.drop(index=idx,axis=0)
#         perf_df= new_result.append(perf_df, ignore_index=True)
        
#     mean_perf = pd.DataFrame(columns = perf_df.keys())
#     mean_perf = mean_perf.append({"dataset":"average performance","win(sec)":"-"},ignore_index=True)
#     for key in perf_df.keys():
#         if key.lower() != "dataset" and  key.lower() != "win(sec)":
#             mean_perf[key].at[0] = perf_df[key].mean().round(round_decimal)
    
#     perf_df = perf_df.append(mean_perf,ignore_index=True)
            
#     return perf_df



# def print_episode_metrics(result,old_result= None, round_decimal=3):
#     """
#     print the episode_perf_df result from test_models_episode_metric
#     in suitable order
#     """
#     result_df= result[['dataset','Days' ,'Meal_Hours',"Meal_Counts","win(sec)",
#             "TPR: Individual-Model","TPR: GroupModel","FP/TP: Individual-Model","FP/TP: GroupModel",
#            "TP: Individual-Model","TP: GroupModel",
#            "FP: Individual-Model","FP: GroupModel",
#            "FN: Individual-Model","FN: GroupModel"]]
#     numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']   
#     for key in result_df.columns:
#         if result_df[key].dtype in numerics:
#             #result_df[key] = np.round(result_df[key].values, round_decimal) 
#             for i in range(len(result_df[key])):
#                 result_df[key].at[i] = result_df[key].iloc[i].round(round_decimal)
            
#     if not isinstance(old_result, type(None)):
#         # remove average performance from old results and append new data to table
#         drop_vals = result["dataset"].values.tolist()
#         drop_vals.append("average performance")
#         idx = []
#         for i in range(len(old_result)):
#             if old_result['dataset'].iloc[i] in drop_vals:
#                 idx.append(i)
        
#         #idx =old_result[(old_result['dataset']=="average performance") | (old_result['dataset'].values == result["dataset"].values)].index
#         print("index",idx)
#         new_result = old_result.drop(index=idx,axis=0)
#         result_df= new_result.append(result_df, ignore_index=True)
    
#     mean_perf = pd.DataFrame(columns = result_df.keys())
#     mean_perf = mean_perf.append({"dataset":"average performance","win(sec)":"-",'Days':"-" ,
#                                   'Meal_Hours':"-","Meal_Counts":"-"},ignore_index=True)
#     for key in mean_perf.keys():
#         if key not in ['dataset','Days' ,'Meal_Hours',"Meal_Counts","win(sec)"]:
#             mean_perf[key].at[0] = result_df[key].mean().round(round_decimal)
    
#     result_df = result_df.append(mean_perf,ignore_index=True)
#     return result_df

# %%
# old_result= episode_comparison_perf
# result =episode_perf2#.head(1)
# # old_result[(old_result['dataset']=="average performance") | (old_result['dataset'] == result["dataset"].values[0])]
# result["dataset"].values
# Out:
# array(['tianyi', 'james'], dtype=object)

# %%
episode_comparison_perf_2 = print_episode_metrics(episode_perf2,old_result= episode_comparison_perf)
episode_comparison_perf_2
# Out:
# index [4]
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4               tianyi   14          5          20      360
# 5                james   12          6          26      360
# 6  average performance    -          -           -        -
#
#   TPR: Individual-Model TPR: GroupModel FP/TP: Individual-Model  \
# 0                 0.969           0.625                   0.613
# 1                 0.923           0.923                   0.417
# 2                 0.667           0.333                     1.2
# 3                 0.763           0.789                   1.759
# 4                   0.6            0.75                   2.167
# 5                 0.923           0.885                   2.083
# ...

# %%
time_comparison_perf_2 = print_time_metrics(time_perf2,old_result=time_comparison_perf)
time_comparison_perf_2
# Out:
# index [4]
#                dataset win(sec) WAcc: GroupModel WAcc2: GroupModel  \
# 0              wenkanw      360            0.779             0.762
# 1                 adam      360            0.956             0.947
# 2               lawler      360            0.605             0.616
# 3              shaurya      360            0.759             0.734
# 4               tianyi      360            0.833             0.828
# 5                james      360            0.787             0.787
# 6  average performance        -            0.786             0.779
#
#   WAcc: Individual-Model WAcc2: Individual-Model F1: GroupModel  \
# 0                    0.9                   0.893          0.423
# 1                  0.959                   0.961          0.433
# 2                  0.721                   0.729          0.132
# 3                  0.766                   0.744          0.409
# 4                  0.843                    0.84          0.456
# ...

# %%
save_path = "../results/"
time_comparison_perf_2.to_csv(save_path+"time_metrics/updated_cv_fold5_time_metrics.csv",index=False)
episode_comparison_perf_2.to_csv(save_path+"episode_metrics/updated_cv_fold5_episode_metrics.csv",index=False)

# %%
# # load previous results
# save_path = "../results/"
# time_comparison_perf_2 = pd.read_csv(save_path+"time_metrics/updated_cv_fold5_time_metrics.csv")
# episode_comparison_perf_2 = pd.read_csv(save_path+"episode_metrics/updated_cv_fold5_episode_metrics.csv")

# %%
name_ls = ["wenkanw",'adam',"lawler","shaurya","tianyi","james","cameron","zeyu","mohammad"]
hy_threshold = {}
for name in name_ls:
    hy_threshold[name] = [0.8,0.3]


# %time meal_info, time_perf3,episode_perf3 = cross_validation_metrics(balance_ratio= balance_ratio, model_arch = acti_model, fold_num = 5, winmin=6, stridesec = 5, \
                                                             names= name_ls,model_name= "acti_model", \
                                                             random_seed=random_seed,  test_balance=False, re_train =False, \
                                                             test_CAD=False, metrics =['time','episode'], load_data =True, ind_threshold =hy_threshold)

episode_perf3 = pd.merge(left=meal_info,right=episode_perf3,on="dataset")

# %%
print_episode_metrics(episode_perf3)
# Out:
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4               tianyi   14          5          20      360
# 5                james   12          6          26      360
# 6              cameron   10          5          22      360
# 7                 zeyu   12         10          22      360
# 8             mohammad    6          4           8      360
# 9  average performance    -          -           -        -
#
#   TPR: Individual-Model TPR: GroupModel FP/TP: Individual-Model  \
# 0                 0.969           0.625                   0.613
# 1                 0.923           0.923                   0.417
# 2                 0.667           0.333                     1.2
# ...

# %%
print_time_metrics(time_perf3)
# Out:
#                dataset win(sec) WAcc: GroupModel WAcc2: GroupModel  \
# 0              wenkanw      360            0.779             0.769
# 1                 adam      360            0.956             0.946
# 2               lawler      360            0.605             0.622
# 3              shaurya      360            0.759             0.741
# 4               tianyi      360            0.833             0.834
# 5                james      360            0.787              0.79
# 6              cameron      360            0.641             0.686
# 7                 zeyu      360            0.837             0.817
# 8             mohammad      360            0.639             0.588
# 9  average performance        -             0.76             0.755
#
#   WAcc: Individual-Model WAcc2: Individual-Model F1: GroupModel  \
# 0                    0.9                   0.895          0.423
# 1                  0.959                   0.962          0.433
# ...

# %%
time_comparison_perf_3 = print_time_metrics(time_perf3)
episode_comparison_perf_3 = print_episode_metrics(episode_perf3)

# %%
save_path = "../results/"
time_comparison_perf_3.to_csv(save_path+"time_metrics/final_updated_cv_fold5_time_metrics.csv",index=False)
episode_comparison_perf_3.to_csv(save_path+"episode_metrics/final_updated_cv_fold5_episode_metrics.csv",index=False)

# %%
time_comparison_perf_3.to_csv(save_path+"time_metrics/group_param_updated_cv_fold5_time_metrics.csv",index=False)
episode_comparison_perf_3.to_csv(save_path+"episode_metrics/group_param_updated_cv_fold5_episode_metrics.csv",index=False)

# %%
# print_episode_metrics(episode_perf3)
# Out:
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              cameron   10          5          22      360
# 1                 zeyu   12         10          22      360
# 2             mohammad    6          4           8      360
# 3  average performance    -          -           -        -
#
#   TPR: Individual-Model TPR: GroupModel FP/TP: Individual-Model  \
# 0                 0.636           0.773                   4.286
# 1                 0.909           0.909                    0.85
# 2                 0.625           0.875                     5.6
# 3                 0.723           0.852                   3.579
#
#   FP/TP: GroupModel TP: Individual-Model TP: GroupModel FP: Individual-Model  \
# 0             3.647                   14             17                   60
# 1              0.65                   20             20                   17
# 2             3.857                    5              7                   28
# ...

# %%
# print_time_metrics(time_perf3)
# Out:
#                dataset win(sec) WAcc: GroupModel WAcc2: GroupModel  \
# 0              cameron      360            0.641             0.686
# 1                 zeyu      360            0.837             0.817
# 2             mohammad      360            0.639             0.588
# 3  average performance        -            0.706             0.697
#
#   WAcc: Individual-Model WAcc2: Individual-Model F1: GroupModel  \
# 0                  0.614                    0.69          0.113
# 1                  0.885                   0.873          0.611
# 2                  0.574                   0.488          0.153
# 3                  0.691                   0.684          0.292
#
#   F1: Individual-Model Precision: GroupModel Precision: Individual-Model  \
# 0                 0.12                 0.062                       0.072
# 1                0.737                 0.521                       0.687
# 2                0.056                  0.11                       0.039
# ...

# %% [markdown]
# # 4. Search and apply the best parameters for individual models

# %% [markdown]
# ## 4.1 Search the best parameters

# %%
datasets = create_datasets(names = name_ls)
# Out:
# Loading Dataset ...
# Loading File:  ../data/IndividualData/wenkanw-data/11-14-20/11-14-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/10-13-20/10-13-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/10-9-20/10-10-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/11-21-20/Dinner/Dinner.shm
# Loading File:  ../data/IndividualData/wenkanw-data/9-17-20/9-17-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/9-29-20/9-29-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/11-22-20/Lunch/Lunch.shm
# Loading File:  ../data/IndividualData/wenkanw-data/11-21-20/lunch/lunch.shm
# Loading File:  ../data/IndividualData/wenkanw-data/10-9-20/10-9-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/11-18-20/11-18-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/10-14-20/10-14-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/10-12-20/10-12-20.shm
# ...

# %%
def find_optimal_threshold(threshold_results,mode="min_fp", min_tpr= 0.85, max_fp=1.):
    """
    To find the optimal threshold for each individual model, based on threshold_results from  function test_threshold_cv()
    
    threshold_results: output dataframe from test_threshold_cv() function
    """
    best_threshold = pd.DataFrame()
    threshold_results["ratio"] = threshold_results["TP"].values/ (threshold_results["TP"].values+threshold_results["FN"].values +threshold_results["FP"].values)
    for person in threshold_results["dataset"].unique():
        
        df= threshold_results.loc[threshold_results['dataset']==person]
        if mode =="min_tpr":
            # find min FP/TP with TPR inside range
            th_df= df.loc[df["TPR"]>=min_tpr]
            if len(th_df) == 0:
                df= df.iloc[df["FP/TP"].argmin()]
            else:
                df = th_df.iloc[th_df["FP/TP"].argmin()]
        elif mode == "max_fp":
            # find max TPR with FP/TP inside range
            th_df = df.loc[df["FP/TP"]<=max_fp]
            
            if len(th_df) == 0:
                df= df.iloc[df["TPR"].argmax()]
            else:
                df= th_df.iloc[th_df["TPR"].argmax()]
        else:
            df = df.iloc[df["ratio"].argmax()]
            
                
        best_threshold = best_threshold.append(df)
        thresholds = {}
        for name in best_threshold['dataset'].values:
            thresholds[name] = [ best_threshold[best_threshold['dataset']==name]['Ts'].values[0] ,
                                best_threshold[best_threshold['dataset']==name]['Te'].values[0] ]
        #best_threshold[["dataset","Ts","Te"]]
    best_threshold = best_threshold[["dataset","Ts","Te","TPR","FP/TP","TP","FP","FN"]]
    return best_threshold , thresholds

# %%
ts_ls = [0.5,0.55, 0.6,0.65, 0.7,0.75,0.8,0.85]
te_ls = [0.1,0.15,0.2,0.25,0.3,0.35,0.4,0.45]

# %time threshold_results =  test_threshold_cv(datasets,ts_ls,te_ls)
# Out:
# /home/wenkanw/.conda/envs/mlenv/lib/python3.8/site-packages/sklearn/model_selection/_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# ...
# 100%|██████████| 4/4 [00:00<00:00, 564.79it/s]
# Segmentation Completed.
# total_meal: 32 TP:  6 FP:  8 FN:  1
# Segmentation Completed.
# total_meal: 32 TP:  7 FP:  4 FN:  0
# ...
# 100%|██████████| 3/3 [00:00<00:00, 373.64it/s]
# Segmentation Completed.
# total_meal: 32 TP:  6 FP:  16 FN:  0
# Segmentation Completed.
# total_meal: 32 TP:  7 FP:  4 FN:  0
# ...
# 100%|██████████| 4/4 [00:00<00:00, 391.03it/s]
# Segmentation Completed.
# total_meal: 32 TP:  5 FP:  6 FN:  0
#    dataset   Ts   Te  TP  FN  FP    TPR  FP/TP
# 0  wenkanw  0.5  0.1  31   1  38  0.969  1.226
# Segmentation Completed.
# total_meal: 32 TP:  6 FP:  8 FN:  1
# ...
# 100%|██████████| 3/3 [00:00<00:00, 280.17it/s]
# ...

# %%
# fix boundary of tpr, then find best fp
# improve FP/TP performance
best_threshold_mtpr ,hythreshold2  = find_optimal_threshold(threshold_results,min_tpr= 0.80, max_fp=3, mode= "min_tpr")
best_threshold_mtpr
# Out:
#       dataset    Ts    Te    TPR  FP/TP    TP    FP    FN
# 56    wenkanw  0.85  0.10  0.969  0.484  31.0  15.0   1.0
# 120      adam  0.85  0.10  0.923  0.292  24.0   7.0   2.0
# 134    lawler  0.50  0.40  0.817  1.735  49.0  85.0  11.0
# 216   shaurya  0.65  0.10  0.816  1.774  31.0  55.0   7.0
# 280    tianyi  0.65  0.10  0.800  2.562  16.0  41.0   4.0
# 376     james  0.85  0.10  0.923  1.458  24.0  35.0   2.0
# 392   cameron  0.55  0.10  0.818  1.833  18.0  33.0   4.0
# 507      zeyu  0.85  0.25  0.909  0.650  20.0  13.0   2.0
# 560  mohammad  0.80  0.10  0.625  4.600   5.0  23.0   3.0

# %%
# fix boundary of fp, then find best tpr
# improve TPR performance
best_threshold_mfp ,hythreshold2  = find_optimal_threshold(threshold_results,min_tpr= 0.80, max_fp=2, mode= "max_fp")
best_threshold_mfp
# Out:
#       dataset    Ts    Te    TPR  FP/TP    TP    FP    FN
# 0     wenkanw  0.50  0.10  0.969  1.226  31.0  38.0   1.0
# 64       adam  0.50  0.10  0.962  0.640  25.0  16.0   1.0
# 131    lawler  0.50  0.25  0.817  1.837  49.0  90.0  11.0
# 195   shaurya  0.50  0.25  0.921  1.943  35.0  68.0   3.0
# 296    tianyi  0.75  0.10  0.650  2.000  13.0  26.0   7.0
# 352     james  0.70  0.10  1.000  1.808  26.0  47.0   0.0
# 384   cameron  0.50  0.10  0.818  2.000  18.0  36.0   4.0
# 448      zeyu  0.50  0.10  0.909  1.800  20.0  36.0   2.0
# 512  mohammad  0.50  0.10  0.625  6.600   5.0  33.0   3.0

# %%
# fix boundary of fp, then find best tpr
# improve TPR performance
best_threshold_ratio ,hythreshold2  = find_optimal_threshold(threshold_results,min_tpr= 0, max_fp=0, mode= "ratio")
best_threshold_ratio
# Out:
#       dataset    Ts    Te    TPR  FP/TP    TP    FP    FN
# 56    wenkanw  0.85  0.10  0.969  0.484  31.0  15.0   1.0
# 120      adam  0.85  0.10  0.923  0.292  24.0   7.0   2.0
# 176    lawler  0.80  0.10  0.650  1.077  39.0  42.0  21.0
# 248   shaurya  0.85  0.10  0.737  1.214  28.0  34.0  10.0
# 312    tianyi  0.85  0.10  0.600  1.417  12.0  17.0   8.0
# 376     james  0.85  0.10  0.923  1.458  24.0  35.0   2.0
# 440   cameron  0.85  0.10  0.773  1.588  17.0  27.0   5.0
# 507      zeyu  0.85  0.25  0.909  0.650  20.0  13.0   2.0
# 560  mohammad  0.80  0.10  0.625  4.600   5.0  23.0   3.0

# %%
from visualization import *

def plot_threshold_results(threshold_results, te_val = 0.1, ts_val=0.6,figsize=(12,10),legend_out=True, grid =False):
    """
    plot threshold results generated from test_threshold_csv()  function in cross_validation.py file
    """
    print("Fixed Te, Change Ts")
    fig, ax= plt.subplots(2,2, figsize=figsize)
    
    for j in range(2):
            ax[0,j].set_xlim(threshold_results['Ts'].min(),threshold_results['Ts'].max())
    
    for j in range(2):
            ax[1,j].set_xlim(threshold_results['Te'].min(),threshold_results['Te'].max())
            
    th_df = threshold_results[(threshold_results['Te']==te_val)]
    
    fig_ts1 = sns.lineplot(data=th_df, x="Ts", y= "TPR", hue="dataset",ax=ax[0,0])
    fig_ts2 = sns.lineplot(data=th_df, x="Ts", y= "FP/TP", hue="dataset",ax=ax[0,1])
    _ = ax[0,0].set_title("Te = "+str(te_val))
    _ = ax[0,1].set_title("Te = "+str(te_val))

    
    th_df = threshold_results[(threshold_results['Ts']==ts_val)]
    fig_te1 = sns.lineplot(data=th_df, x="Te", y= "TPR", hue="dataset",ax=ax[1,0])
    fig_te2 = sns.lineplot(data=th_df, x="Te", y= "FP/TP", hue="dataset",ax=ax[1,1])
    _ = ax[1,0].set_title("Ts = "+str(ts_val))
    _ = ax[1,1].set_title("Ts = "+str(ts_val))
    if grid:
        fig_ts1.grid()
        fig_ts2.grid()
        fig_te1.grid()
        fig_te2.grid()
    if not legend_out :
        fig_ts1.legend(loc="upper right")
        fig_ts2.legend(loc="upper right")
        fig_te1.legend(loc="upper right")
        fig_te2.legend(loc="upper right")
    else:
        fig_te2.legend_.remove()
        fig_ts1.legend_.remove()
        fig_te1.legend_.remove()
        fig_ts2.legend(loc=2, bbox_to_anchor=(1.05,1.0),borderaxespad = 0.)
    
    return [fig_ts1,fig_ts2], [fig_te1,fig_te2]

def save_figs(fig_ts, fig_te, dpi=400,fig_path = "../results/images/",prefix=""):
    
    fig = fig_ts[0].get_figure()
    fig.savefig(fig_path+prefix+"fig_ts1", dpi = dpi)
    fig = fig_ts[1].get_figure()
    fig.savefig(fig_path+prefix+"fig_ts2", dpi = dpi)
    fig = fig_te[0].get_figure()
    fig.savefig(fig_path+prefix+"fig_te1", dpi = dpi)
    fig = fig_te[1].get_figure()
    fig.savefig(fig_path+prefix+"fig_te2", dpi = dpi)

# %%
## Save threshold results
threshold_results.to_csv("../results/hysteresis_results/cv_threshold_results.csv",index= False)
best_threshold_mtpr.to_csv("../results/hysteresis_results/cv_best_thresholds_mintpr.csv",index = False)
best_threshold_mfp.to_csv("../results/hysteresis_results/cv_best_thresholds_maxfp.csv",index = False)
best_threshold_ratio.to_csv("../results/hysteresis_results/cv_best_thresholds_ratio.csv",index = False)

# %%
## load threshold results
threshold_results= pd.read_csv("../results/hysteresis_results/cv_threshold_results.csv")
best_threshold_mtpr=pd.read_csv("../results/hysteresis_results/cv_best_thresholds_mintpr.csv")
best_threshold_mfp=pd.read_csv("../results/hysteresis_results/cv_best_thresholds_maxfp.csv")
best_threshold_ratio=pd.read_csv("../results/hysteresis_results/cv_best_thresholds_ratio.csv")

# %%
fig_ts, fig_te = plot_threshold_results(threshold_results,te_val = 0.1, ts_val=0.6, figsize = (15, 10),grid=True)
save_figs(fig_ts, fig_te, dpi=400,fig_path = "../results/images/",prefix="1_")
# Out:
# Fixed Te, Change Ts

# %%
fig_ts, fig_te = plot_threshold_results(threshold_results,te_val = 0.3, ts_val=0.8, figsize = (15, 10),grid=True)
save_figs(fig_ts, fig_te, dpi=400,fig_path = "../results/images/",prefix="2_")
# Out:
# Fixed Te, Change Ts

# %%
# ! ls ../models/tianyi_models
# ! ls ../results/hysteresis_results/

# %%
# person='tianyi'
# model_name = '../models/{}_models/cv_fold_{}_acti_model_M_F_6.000000Min.h5'.format(person, 0)
# print(model_name)
# m = tf.keras.models.load_model(model_name)

# %% [markdown]
# ## 4.2 Apply individual parameters to Individual models and compare with group model

# %%
## load threshold results
threshold_results= pd.read_csv("../results/hysteresis_results/cv_threshold_results.csv")
best_threshold_mtpr=pd.read_csv("../results/hysteresis_results/cv_best_thresholds_mintpr.csv")
best_threshold_mfp=pd.read_csv("../results/hysteresis_results/cv_best_thresholds_maxfp.csv")
best_threshold_ratio=pd.read_csv("../results/hysteresis_results/cv_best_thresholds_ratio.csv")

# %%
# best_threshold
# x = best_threshold[['dataset','Ts','Te']].T

# %%
persons = ['wenkanw','adam','lawler','shaurya','tianyi','james','cameron','zeyu','mohammad']
ind_thresholds_mtpr = {}
for p in persons:
    ind_thresholds_mtpr[p]=[]
    ind_thresholds_mtpr[p].append(best_threshold_mtpr[best_threshold_mtpr['dataset']==p]['Ts'].values[0])
    ind_thresholds_mtpr[p].append(best_threshold_mtpr[best_threshold_mtpr['dataset']==p]['Te'].values[0])
ind_thresholds_mtpr
# Out:
# {'wenkanw': [0.85, 0.1],
#  'adam': [0.85, 0.1],
#  'lawler': [0.5, 0.4],
#  'shaurya': [0.65, 0.1],
#  'tianyi': [0.65, 0.1],
#  'james': [0.85, 0.1],
#  'cameron': [0.55, 0.1],
#  'zeyu': [0.85, 0.25],
#  'mohammad': [0.8, 0.1]}

# %%
persons = ['wenkanw','adam','lawler','shaurya','tianyi','james','cameron','zeyu','mohammad']
ind_thresholds_mfp = {}
for p in persons:
    ind_thresholds_mfp[p]=[]
    ind_thresholds_mfp[p].append(best_threshold_mfp[best_threshold_mfp['dataset']==p]['Ts'].values[0])
    ind_thresholds_mfp[p].append(best_threshold_mfp[best_threshold_mfp['dataset']==p]['Te'].values[0])
ind_thresholds_mfp
# Out:
# {'wenkanw': [0.5, 0.1],
#  'adam': [0.5, 0.1],
#  'lawler': [0.5, 0.25],
#  'shaurya': [0.5, 0.25],
#  'tianyi': [0.75, 0.1],
#  'james': [0.7, 0.1],
#  'cameron': [0.5, 0.1],
#  'zeyu': [0.5, 0.1],
#  'mohammad': [0.5, 0.1]}

# %%
persons = ['wenkanw','adam','lawler','shaurya','tianyi','james','cameron','zeyu','mohammad']
ind_thresholds_ratio = {}
for p in persons:
    ind_thresholds_ratio[p]=[]
    ind_thresholds_ratio[p].append(best_threshold_ratio[best_threshold_ratio['dataset']==p]['Ts'].values[0])
    ind_thresholds_ratio[p].append(best_threshold_ratio[best_threshold_ratio['dataset']==p]['Te'].values[0])
ind_thresholds_ratio
# Out:
# {'wenkanw': [0.85, 0.1],
#  'adam': [0.85, 0.1],
#  'lawler': [0.8, 0.1],
#  'shaurya': [0.85, 0.1],
#  'tianyi': [0.85, 0.1],
#  'james': [0.85, 0.1],
#  'cameron': [0.85, 0.1],
#  'zeyu': [0.85, 0.25],
#  'mohammad': [0.8, 0.1]}

# %%
# fix tpr, improve FP


# %time meal_info, time_perf4,episode_perf4 = cross_validation_metrics(balance_ratio= balance_ratio, model_arch = acti_model, fold_num = 5, winmin=6, stridesec = 5, \
                                                             names= persons,model_name= "acti_model", \
                                                             random_seed=random_seed,  test_balance=False, re_train =False, \
                                                             test_CAD=False, metrics =['episode'], load_data =False, ind_threshold =ind_thresholds_mtpr)

episode_perf4 = pd.merge(left=meal_info,right=episode_perf4,on="dataset")

# %%
# update episode metric
episode_metrics_individual_param_mtpr = print_episode_metrics(episode_perf4)
episode_metrics_individual_param_mtpr
# Out:
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4               tianyi   14          5          20      360
# 5                james   12          6          26      360
# 6              cameron   10          5          22      360
# 7                 zeyu   12         10          22      360
# 8             mohammad    6          4           8      360
# 9  average performance    -          -           -        -
#
#   TPR: Individual-Model TPR: GroupModel FP/TP: Individual-Model  \
# 0                 0.969           0.625                   0.484
# 1                 0.923           0.923                   0.292
# 2                 0.817           0.333                   1.735
# ...

# %%
# fix fp, improve TPR


# %time meal_info, time_perf5,episode_perf5 = cross_validation_metrics(balance_ratio= balance_ratio, model_arch = acti_model, fold_num = 5, winmin=6, stridesec = 5, \
                                                             names= persons,model_name= "acti_model", \
                                                             random_seed=random_seed,  test_balance=False, re_train =False, \
                                                             test_CAD=False, metrics =['episode'], load_data =False, ind_threshold =ind_thresholds_mfp)

episode_perf5 = pd.merge(left=meal_info,right=episode_perf5,on="dataset")

# %%
# update episode metric
episode_metrics_individual_param_mfp = print_episode_metrics(episode_perf5)
episode_metrics_individual_param_mfp
# Out:
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4               tianyi   14          5          20      360
# 5                james   12          6          26      360
# 6              cameron   10          5          22      360
# 7                 zeyu   12         10          22      360
# 8             mohammad    6          4           8      360
# 9  average performance    -          -           -        -
#
#   TPR: Individual-Model TPR: GroupModel FP/TP: Individual-Model  \
# 0                 0.969           0.625                   1.226
# 1                 0.962           0.923                    0.64
# 2                 0.817           0.333                   1.837
# ...

# %%
# fix fp, improve TPR


# %time meal_info, time_perf6,episode_perf6 = cross_validation_metrics(balance_ratio= balance_ratio, model_arch = acti_model, fold_num = 5, winmin=6, stridesec = 5, \
                                                             names= persons,model_name= "acti_model", \
                                                             random_seed=random_seed,  test_balance=False, re_train =False, \
                                                             test_CAD=False, metrics =['episode'], load_data =False, ind_threshold =ind_thresholds_ratio)

episode_perf6 = pd.merge(left=meal_info,right=episode_perf6,on="dataset")
# Out:
# /home/wenkanw/.conda/envs/mlenv/lib/python3.8/site-packages/sklearn/model_selection/_split.py:293: FutureWarning: Setting a random_state has no effect since shuffle is False. This will raise an error in 0.24. You should leave random_state to its default (None), or set shuffle=True.
#   warnings.warn(
# Loading Dataset ...
# Loading File:  ../data/IndividualData/wenkanw-data/11-14-20/11-14-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/10-13-20/10-13-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/10-9-20/10-10-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/11-21-20/Dinner/Dinner.shm
# Loading File:  ../data/IndividualData/wenkanw-data/9-17-20/9-17-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/9-29-20/9-29-20.shm
# Loading File:  ../data/IndividualData/wenkanw-data/11-22-20/Lunch/Lunch.shm
# Loading File:  ../data/IndividualData/wenkanw-data/11-21-20/lunch/lunch.shm
# ...

# %%
# update episode metric
episode_metrics_individual_param_ratio = print_episode_metrics(episode_perf6)
episode_metrics_individual_param_ratio
# Out:
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4               tianyi   14          5          20      360
# 5                james   12          6          26      360
# 6              cameron   10          5          22      360
# 7                 zeyu   12         10          22      360
# 8             mohammad    6          4           8      360
# 9  average performance    -          -           -        -
#
#   TPR: Individual-Model TPR: GroupModel FP/TP: Individual-Model  \
# 0                 0.969           0.625                   0.484
# 1                 0.923           0.923                   0.292
# 2                  0.65           0.333                   1.077
# ...

# %%
# update episode metric
save_path = "../results/"
episode_metrics_individual_param_mtpr.to_csv(save_path+"episode_metrics/updated_cv_fold5_episode_metrics_individual_param_mtpr.csv",index=False)
episode_metrics_individual_param_mfp.to_csv(save_path+"episode_metrics/updated_cv_fold5_episode_metrics_individual_param_mfp.csv",index=False)
episode_metrics_individual_param_ratio.to_csv(save_path+"episode_metrics/updated_cv_fold5_episode_metrics_individual_param_ratio.csv",index=False)

# %%
save_path = "../results/"
perf_mtpr = pd.read_csv(save_path+"episode_metrics/updated_cv_fold5_episode_metrics_individual_param_mtpr.csv")
perf_mfp = pd.read_csv(save_path+"episode_metrics/updated_cv_fold5_episode_metrics_individual_param_mfp.csv")
perf_ratio = pd.read_csv(save_path+"episode_metrics/updated_cv_fold5_episode_metrics_individual_param_ratio.csv")

# %%
perf_mtpr
# Out:
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4               tianyi   14          5          20      360
# 5                james   12          6          26      360
# 6              cameron   10          5          22      360
# 7                 zeyu   12         10          22      360
# 8             mohammad    6          4           8      360
# 9  average performance    -          -           -        -
#
#    TPR: Individual-Model  TPR: GroupModel  FP/TP: Individual-Model  \
# 0                  0.969            0.625                    0.484
# 1                  0.923            0.923                    0.292
# 2                  0.817            0.333                    1.735
# ...

# %%
perf_mfp
# Out:
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4               tianyi   14          5          20      360
# 5                james   12          6          26      360
# 6              cameron   10          5          22      360
# 7                 zeyu   12         10          22      360
# 8             mohammad    6          4           8      360
# 9  average performance    -          -           -        -
#
#    TPR: Individual-Model  TPR: GroupModel  FP/TP: Individual-Model  \
# 0                  0.969            0.625                    1.226
# 1                  0.962            0.923                    0.640
# 2                  0.817            0.333                    1.837
# ...

# %%
perf_ratio
# Out:
#                dataset Days Meal_Hours Meal_Counts win(sec)  \
# 0              wenkanw   17          7          32      360
# 1                 adam   14          3          26      360
# 2               lawler   23          7          60      360
# 3              shaurya   13          9          38      360
# 4               tianyi   14          5          20      360
# 5                james   12          6          26      360
# 6              cameron   10          5          22      360
# 7                 zeyu   12         10          22      360
# 8             mohammad    6          4           8      360
# 9  average performance    -          -           -        -
#
#    TPR: Individual-Model  TPR: GroupModel  FP/TP: Individual-Model  \
# 0                  0.969            0.625                    0.484
# 1                  0.923            0.923                    0.292
# 2                  0.650            0.333                    1.077
# ...
