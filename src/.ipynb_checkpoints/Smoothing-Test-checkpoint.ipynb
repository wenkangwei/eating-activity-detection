# %%
data= "0.574462891 \
0.245727539 \
0.476196289 \
-0.73840332 \
0.206665039 \
-0.247802734 \
-0.382568359 \
-0.102172852 \
-0.252197266 \
0.114257813 \
0.078369141 \
-0.011230469 \
-0.035888672 \
0.165649414 \
0.086547852 \
-0.031860352 \
-0.256835938 \
0.052856445 \
-0.234008789 \
-0.234741211 \
-0.050415039 \
0.003662109 \
-0.397949219 \
-0.075073242 \
-0.129394531 \
-0.175170898 \
-0.185180664 \
-0.358276367 \
-0.22668457 \
-0.255126953 \
-0.489868164 \
-0.160644531 \
-0.187988281 \
-0.428466797 \
-0.19934082 \
-0.119873047"
f_data = [float(s) for s in data.split(" ")]

# %%
import pandas as pd
# if don't add skiprows=1, all data will be considered as index! Need to skip the first line of data
df = pd.read_csv("MPL_TEST_Session2_Shimmer_Calibrated.csv",sep='\t',skiprows=1)
df = df.iloc[:,:16]
df.head()
# Out:
#   Shimmer_Timestamp_CAL Shimmer_RealTime_CAL    Shimmer_GSR_CAL  \
# 0                 msecs                msecs              kOhms
# 1      822830.749511719     1600307819190.55  -40.0136046255727
# 2      823078.369140625     1600307819438.17  -40.0136046255727
# 3       823145.01953125     1600307819504.82  -40.0136046255727
# 4      823211.669921875     1600307819571.47  -40.0136046255727
#
#   Shimmer_Quat_MPL_6DOF_W_CAL Shimmer_Quat_MPL_6DOF_X_CAL  \
# 0                    no units                    no units
# 1           0.408899933099747           0.881388664245606
# 2           0.316589713096619           0.926730155944824
# 3           0.177900910377502           0.956785261631012
# 4            0.11781457066536           0.947972655296326
#
#   Shimmer_Quat_MPL_6DOF_Y_CAL Shimmer_Quat_MPL_6DOF_Z_CAL  \
# 0                    no units                    no units
# 1          -0.236547723412514       -1.48080289363861e-07
# 2          -0.202223032712936         0.00692293979227543
# 3           -0.22879359126091         -0.0238071493804455
# 4          -0.214594423770905          -0.203510746359825
#
#   Shimmer_Gyro_MPU_MPL_X_CAL Shimmer_Gyro_MPU_MPL_Y_CAL  \
# 0                    deg/sec                    deg/sec
# 1            -112.3681640625                69.86328125
# 2            190.42724609375            -97.92236328125
# 3            185.05615234375           -249.77783203125
# 4             333.6767578125            -11.49658203125
#
#   Shimmer_Gyro_MPU_MPL_Z_CAL Shimmer_Accel_MPU_MPL_X_CAL  \
# 0                    deg/sec                   m/(sec^2)
# 1          -2.20216369628906             0.1541748046875
# 2          -7.69532775878906               0.01416015625
# 3           29.2309417724609             -0.124755859375
# 4          -106.999526977539            -0.6082763671875
#
#   Shimmer_Accel_MPU_MPL_Y_CAL Shimmer_Accel_MPU_MPL_Z_CAL  \
# 0                   m/(sec^2)                   m/(sec^2)
# 1              0.574462890625          -0.530471801757813
# 2             0.2457275390625          -0.691238403320313
# 3             0.4761962890625           -1.27388000488281
# 4            -0.7384033203125          -0.657669067382813
#
#   Shimmer_Mag_MPU_MPL_X_CAL Shimmer_Mag_MPU_MPL_Y_CAL  \
# 0                    uTesla                    uTesla
# 1         -141.202102661133          86.4689178466797
# 2          -139.40217590332          91.2687225341797
# 3         -134.902359008789          102.068283081055
# 4         -120.802932739258          103.568222045898
#
#   Shimmer_Mag_MPU_MPL_Z_CAL
# 0                    uTesla
# 1           417.83821105957
# 2           420.23811340332
# 3          419.038162231445
# 4          404.338760375977

# %%
df = df.iloc[:,[0,1,7,8,9,10,11,12]]
df

# %%
df.rename({"Shimmer_Timestamp_CAL":"timestamp","Shimmer_RealTime_CAL":"realtime",
           "Shimmer_Gyro_MPU_MPL_X_CAL":"gyr_x","Shimmer_Gyro_MPU_MPL_Y_CAL":"gyr_y","Shimmer_Gyro_MPU_MPL_Z_CAL":"gyr_z",
           "Shimmer_Accel_MPU_MPL_X_CAL":"acc_x","Shimmer_Accel_MPU_MPL_Y_CAL":"acc_y","Shimmer_Accel_MPU_MPL_Z_CAL":"acc_z"},
          axis="columns")
# Out:
#               timestamp          realtime            gyr_x             gyr_y  \
# 0                 msecs             msecs          deg/sec           deg/sec
# 1      822830.749511719  1600307819190.55  -112.3681640625       69.86328125
# 2      823078.369140625  1600307819438.17  190.42724609375   -97.92236328125
# 3       823145.01953125  1600307819504.82  185.05615234375  -249.77783203125
# 4      823211.669921875  1600307819571.47   333.6767578125   -11.49658203125
# ...                 ...               ...              ...               ...
# 71231       5.57138e+06       1.60031e+12        -0.556641          0.119614
# 71232       5.57145e+06       1.60031e+12         0.297852         -0.795914
# 71233       5.57151e+06       1.60031e+12        -0.251465       -0.00245667
# 71234       5.57158e+06       1.60031e+12         0.480957          0.913071
# 71235       5.57165e+06       1.60031e+12         0.480957         -0.185562
#
#                    gyr_z             acc_x             acc_y  \
# 0                deg/sec         m/(sec^2)         m/(sec^2)
# 1      -2.20216369628906   0.1541748046875    0.574462890625
# 2      -7.69532775878906     0.01416015625   0.2457275390625
# 3       29.2309417724609   -0.124755859375   0.4761962890625
# 4      -106.999526977539  -0.6082763671875  -0.7384033203125
# ...                  ...               ...               ...
# 71231         -0.0268707        -0.0458984         -0.194092
# 71232            0.33934        -0.0505371         -0.199219
# 71233             1.1328        -0.0319824         -0.216675
# 71234           -1.18654        -0.0351562           -0.2052
# 71235          -0.148941        -0.0351562         -0.191528
#
#                     acc_z
# 0               m/(sec^2)
# 1      -0.530471801757813
# 2      -0.691238403320313
# 3       -1.27388000488281
# 4      -0.657669067382813
# ...                   ...
# 71231             0.96904
# 71232            0.978683
# 71233            0.985275
# 71234            0.981003
# 71235            0.968185
#
# [71236 rows x 8 columns]

# %%
import numpy as np
import matplotlib.pyplot as plt
def signal_samples(t):
    np.random.seed(int(np.random.random()*10e+8))
    return np.sin(2 * np.pi * 1 * t)  + np.sin(2 * np.pi * 20 *t)

B = 30.0
f_s = 2 * B
delta_f = 0.01
N = int(f_s / delta_f)
T = N / f_s
t = np.linspace(0, T, N)
# f_t = signal_samples(t)
f_t = f_data
t = [i*0.25 for i in range(len(f_data))]
N= len(t)
fig, axes = plt.subplots(2, 1, figsize=(16, 6), sharey=True)
axes[0].plot(t, f_t)
axes[0].set_xlabel("time (s)")
axes[0].set_ylabel("signal")
axes[0].set_xlim(0, 10)
axes[1].plot(t, f_t)
axes[1].set_xlim(0, 5)
axes[1].set_xlabel("time (s)")
plt.show()

from scipy import fftpack
F = fftpack.fft(f_t)
f = fftpack.fftfreq(N, 1.0/f_s)
F_filtered = F * (abs(f) < 10)
# F_filtered = np.array([F[i] if F[i] >1.0 and f[i]<10 else 0.000 for i in range(len(F_filtered))  ] )
f_t_filtered = fftpack.ifft(F_filtered)
mask = np.where(f >= 0)

fig, axes = plt.subplots(3, 1, figsize=(8, 8))
axes[0].plot(f[mask], np.log(abs(F[mask])), label="real")
axes[0].plot(B, 0, 'r*', markersize=10)
axes[0].set_ylabel("$\log(|F|)$", fontsize=14)
axes[1].plot(f[mask], abs(F[mask])/N, label="real")

axes[1].set_ylabel("$|F|$", fontsize=14)
axes[2].plot(t, f_t, label='original')
axes[2].plot(t, f_t_filtered.real, color="red", lw = 3, label='filtered')
# axes[2].set_xlim(1, 11)
axes[2].set_xlabel("time (s)", fontsize=14)
axes[2].set_ylabel("$|F|$", fontsize=14)
plt.show()

# %%
F_filtered
# Out:
# array([-3.96276855-0.j        ,  0.12974917-1.96252979j,
#         1.40110042+0.1494189j ,  2.67535369-0.38842786j,
#         1.1953222 -0.94714165j,  0.94457534-0.74125867j,
#         0.        +0.j        ,  0.        +0.j        ,
#         0.        +0.j        ,  0.        +0.j        ,
#        -0.        +0.j        ,  0.        -0.j        ,
#        -0.        +0.j        ,  0.        -0.j        ,
#         0.        +0.j        ,  0.        +0.j        ,
#         0.        +0.j        ,  0.        +0.j        ,
#         0.        +0.j        ,  0.        +0.j        ,
#         0.        +0.j        ,  0.        +0.j        ,
#         0.        +0.j        , -0.        +0.j        ,
#         0.        -0.j        , -0.        +0.j        ,
#         0.        -0.j        ,  0.        +0.j        ,
#         0.        +0.j        ,  0.        +0.j        ,
#         0.        +0.j        ,  0.94457534+0.74125867j,
#         1.1953222 +0.94714165j,  2.67535369+0.38842786j,
#         1.40110042-0.1494189j ,  0.12974917+1.96252979j])

# %%
plt.plot(t, f_t, label='original')
plt.plot(t, f_t_filtered.real, color="red", lw = 3, label='filtered')

# %%
# plt.plot(f[mask], abs(F_filtered[mask])/N, label='original')
# plt.plot(f[mask], F_filtered.real, color="red", lw = 3, label='filtered')
plt.plot(f[mask], abs(F_filtered[mask]), color="red", lw = 3, label='filtered')

# %%
plt.plot(f[mask], abs(F[mask])/N, label="real")

# %%
import matplotlib.pyplot as plt
from scipy import signal
import numpy as np
import pandas as pd
from matplotlib import cm

# data=pd.read_table('./vibdata.txt',header=None,index_col=0,names=['time','acc'])
data = pd.DataFrame({"acc":f_t_filtered.real, "time":t})
data= data.set_index("time")
1/(data.index[1]-data.index[0])
acc=data['acc']
data.plot()

# %%
rate= 15 #48000
Block_size=2 #8192
freqs, times, Sxx = signal.spectrogram(acc, fs=rate, window='hanning',
                                      nperseg=2, noverlap=1,
                                      detrend=False, scaling='spectrum')
plt.figure()
plt.pcolormesh(times, freqs, 20 * np.log10(Sxx/1e-06), cmap='inferno')
plt.clim(70,150)
# plt.ylim(0,10)
plt.colorbar()
plt.ylabel('Frequency [Hz]')
plt.xlabel('Time [s]');
